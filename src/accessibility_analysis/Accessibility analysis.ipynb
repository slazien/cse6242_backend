# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import psycopg2
import sqlalchemy
import geopandas as gpd
import geoalchemy2
import configparser

# %% [markdown]
# ## Fetching data from database

# %%
config = configparser.ConfigParser()
config.read("../../config/config.ini")    
db_params = dict(config['DB'])

conn_string = 'postgresql://{user}:{password}@{host}:{port}/{dbname}'.format(**db_params)
db = sqlalchemy.create_engine(conn_string)
conn = db.connect()
metadata = sqlalchemy.MetaData()

# %%
accessibility_table = sqlalchemy.Table('accessibility_stats', metadata, autoload=True, autoload_with=db)
#Equivalent to 'SELECT * FROM accessibility_stats'
query = sqlalchemy.select([accessibility_table]) 
accessibility = conn.execute(query).fetchall()

# %%
h3_demo_table = sqlalchemy.Table('h3demographics', metadata, autoload=True, autoload_with=db)
#Equivalent to 'SELECT * FROM h3demographics'
query = sqlalchemy.select([h3_demo_table]) 
h3_demo = conn.execute(query).fetchall()

# %%
conn.close()

# %% [markdown]
# ## City accessibility comparision

# %%
acc_df = pd.DataFrame(accessibility)
acc_df
# Out:
#               id  cityid categorytype             poi_category timeofday  \
# 0        1739617       3         Race  Schools and pre-schools   evening
# 1        1739618       3         Race  Schools and pre-schools   evening
# 2        1739619       3         Race  Schools and pre-schools   evening
# 3        1739620       3         Race  Schools and pre-schools   evening
# 4        1739621       3         Race  Schools and pre-schools   evening
# ...          ...     ...          ...                      ...       ...
# 4615485  1739612       3         Race  Schools and pre-schools   evening
# 4615486  1739613       3         Race  Schools and pre-schools   evening
# 4615487  1739614       3         Race  Schools and pre-schools   evening
# 4615488  1739615       3         Race  Schools and pre-schools   evening
# 4615489  1739616       3         Race  Schools and pre-schools   evening
#
#                     h3id  accessibility
# 0        8929a5659dbffff       2.107254
# 1        8929a565a03ffff       3.623966
# 2        8929a565a07ffff       1.772482
# 3        8929a565a0bffff       1.772482
# 4        8929a565a0fffff       1.772482
# ...                  ...            ...
# 4615485  8929a56594fffff       0.620469
# 4615486  8929a565953ffff       0.620469
# 4615487  8929a56595bffff       1.509975
# 4615488  8929a5659c3ffff       2.107254
# 4615489  8929a5659cfffff       2.107254
#
# [4615490 rows x 7 columns]

# %%
h3_demographic_df = pd.DataFrame(h3_demo)
h3_demographic_df
# Out:
#          cityid categorytype                          groupname  \
# 0             4  Age and Sex              Under 18 years female
# 1             4  Age and Sex              18 to 45 years female
# 2             4  Age and Sex              45 to 65 years female
# 3             4  Age and Sex           65 years and over female
# 4             4         Race                              White
# ...         ...          ...                                ...
# 3419970       4         Race  American Indian and Alaska Native
# 3419971       4  Age and Sex                Under 18 years male
# 3419972       4  Age and Sex                18 to 45 years male
# 3419973       4  Age and Sex                45 to 65 years male
# 3419974       4  Age and Sex             65 years and over male
#
#                     h3id  population       id
# 0        8926645a963ffff    0.960630  1898645
# 1        8926645a963ffff    3.307087  1898646
# 2        8926645a963ffff    2.062992  1898647
# 3        8926645a963ffff    3.519685  1898648
# 4        8926645a963ffff   15.574803  1898649
# ...                  ...         ...      ...
# 3419970  8926645a963ffff    0.000000  1898640
# 3419971  8926645a963ffff    1.133858  1898641
# 3419972  8926645a963ffff    1.834646  1898642
# 3419973  8926645a963ffff    1.543307  1898643
# 3419974  8926645a963ffff    2.992126  1898644
#
# [3419975 rows x 6 columns]

# %%
population_filter = h3_demographic_df["categorytype"] == "Age and Sex"
h3_demo_fltrd = h3_demographic_df[population_filter]
h3_demo_fltrd
# Out:
#          cityid categorytype                 groupname             h3id  \
# 0             4  Age and Sex     Under 18 years female  8926645a963ffff
# 1             4  Age and Sex     18 to 45 years female  8926645a963ffff
# 2             4  Age and Sex     45 to 65 years female  8926645a963ffff
# 3             4  Age and Sex  65 years and over female  8926645a963ffff
# 21            4  Age and Sex       Under 18 years male  8926645a937ffff
# ...         ...          ...                       ...              ...
# 3419953       4  Age and Sex  65 years and over female  8926645a967ffff
# 3419971       4  Age and Sex       Under 18 years male  8926645a963ffff
# 3419972       4  Age and Sex       18 to 45 years male  8926645a963ffff
# 3419973       4  Age and Sex       45 to 65 years male  8926645a963ffff
# 3419974       4  Age and Sex    65 years and over male  8926645a963ffff
#
#          population       id
# 0          0.960630  1898645
# 1          3.307087  1898646
# 2          2.062992  1898647
# 3          3.519685  1898648
# 21         1.133858  1898666
# ...             ...      ...
# 3419953    3.519685  1898623
# 3419971    1.133858  1898641
# 3419972    1.834646  1898642
# 3419973    1.543307  1898643
# 3419974    2.992126  1898644
#
# [1094392 rows x 6 columns]

# %%
h3_pop_df = h3_demo_fltrd.groupby(["cityid", "h3id"]).sum()["population"].reset_index()[["h3id", "population"]]
h3_pop_df
# Out:
#                    h3id  population
# 0       8944c100907ffff  256.800000
# 1       8944c100917ffff  266.777778
# 2       8944c100923ffff  256.800000
# 3       8944c100927ffff  123.909091
# 4       8944c10092fffff  256.800000
# ...                 ...         ...
# 136794  8926cbd75cbffff  581.250000
# 136795  8926cbd75cfffff  229.666667
# 136796  8926cbd75d3ffff   70.400000
# 136797  8926cbd75d7ffff  639.000000
# 136798  8926cbd75dbffff  252.000000
#
# [136799 rows x 2 columns]

# %%
acc_df_mrgd = pd.merge(acc_df, h3_pop_df, how='inner', on = 'h3id')
acc_df_mrgd
# Out:
#               id  cityid          categorytype  \
# 0        1739617       3                  Race
# 1        1762442       3           Age and Sex
# 2        1785267       3                Income
# 3        1808092       3                Origin
# 4        1830917       3  Vehicle Availability
# ...          ...     ...                   ...
# 4615485  3441508       4                  Race
# 4615486  3452073       4           Age and Sex
# 4615487  3462638       4                Income
# 4615488  3473203       4                Origin
# 4615489  3483768       4  Vehicle Availability
#
#                             poi_category timeofday             h3id  \
# 0                Schools and pre-schools   evening  8929a5659dbffff
# 1                Schools and pre-schools   evening  8929a5659dbffff
# 2                Schools and pre-schools   evening  8929a5659dbffff
# 3                Schools and pre-schools   evening  8929a5659dbffff
# 4                Schools and pre-schools   evening  8929a5659dbffff
# ...                                  ...       ...              ...
# 4615485  Grocery stores and supermarkets   evening  892664c8b73ffff
# 4615486  Grocery stores and supermarkets   evening  892664c8b73ffff
# 4615487  Grocery stores and supermarkets   evening  892664c8b73ffff
# 4615488  Grocery stores and supermarkets   evening  892664c8b73ffff
# 4615489  Grocery stores and supermarkets   evening  892664c8b73ffff
#
#          accessibility  population
# 0             2.107254    0.000000
# 1             2.107254    0.000000
# 2             4.848244    0.000000
# 3             2.107254    0.000000
# 4             4.848244    0.000000
# ...                ...         ...
# 4615485       0.079719   42.516129
# 4615486       0.079719   42.516129
# 4615487       0.266190   42.516129
# 4615488       0.079719   42.516129
# 4615489       0.266190   42.516129
#
# [4615490 rows x 8 columns]

# %%
category_filter = acc_df_mrgd["categorytype"] == "Age and Sex"
time_filter = acc_df_mrgd["timeofday"] == "afternoon"
acc_df_mrgd_fltrd = acc_df_mrgd[category_filter & time_filter]
acc_df_mrgd_fltrd
# Out:
#               id  cityid categorytype                     poi_category  \
# 11       1647997       3  Age and Sex          Schools and pre-schools
# 26       2587058       3  Age and Sex              Vaccination centers
# 41       1896243       3  Age and Sex             Cinemas and Theaters
# 56       2108145       3  Age and Sex  Grocery stores and supermarkets
# 71       2346308       3  Age and Sex            Clinics and Hospitals
# ...          ...     ...          ...                              ...
# 4615421  3404285       4  Age and Sex  Grocery stores and supermarkets
# 4615456  3404736       4  Age and Sex  Grocery stores and supermarkets
# 4615466  3404908       4  Age and Sex  Grocery stores and supermarkets
# 4615476  3404909       4  Age and Sex  Grocery stores and supermarkets
# 4615481  3394889       4  Age and Sex  Grocery stores and supermarkets
#
#          timeofday             h3id  accessibility  population
# 11       afternoon  8929a5659dbffff       2.107254    0.000000
# 26       afternoon  8929a565a03ffff       2.783466    0.000000
# 41       afternoon  8929a565a03ffff       0.195717    0.000000
# 56       afternoon  8929a565a03ffff      34.469766    0.000000
# 71       afternoon  8929a565a03ffff       0.347431    0.000000
# ...            ...              ...            ...         ...
# 4615421  afternoon  892759359b7ffff       0.870483  318.250000
# 4615456  afternoon  89275936a9bffff       0.527612  117.888889
# 4615466  afternoon  89275936e43ffff       0.527612  119.500000
# 4615476  afternoon  89275936e47ffff       0.527612  119.500000
# 4615481  afternoon  89266450917ffff       0.566062   85.809524
#
# [305659 rows x 8 columns]

# %%
city_pop_df = acc_df_mrgd_fltrd.groupby("cityid").sum()["population"].reset_index()
city_pop_df.columns = ["cityid", "citypop"]

# %%
acc_df_mrgd_fltrd["pop x acc"] = acc_df_mrgd_fltrd["accessibility"] * acc_df_mrgd_fltrd["population"]
acc_df_mrgd_fltrd
# Out:
# <ipython-input-13-655941e8a987>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   acc_df_mrgd_fltrd["pop x acc"] = acc_df_mrgd_fltrd["accessibility"] * acc_df_mrgd_fltrd["population"]
#               id  cityid categorytype                     poi_category  \
# 11       1647997       3  Age and Sex          Schools and pre-schools
# 26       2587058       3  Age and Sex              Vaccination centers
# 41       1896243       3  Age and Sex             Cinemas and Theaters
# 56       2108145       3  Age and Sex  Grocery stores and supermarkets
# 71       2346308       3  Age and Sex            Clinics and Hospitals
# ...          ...     ...          ...                              ...
# 4615421  3404285       4  Age and Sex  Grocery stores and supermarkets
# 4615456  3404736       4  Age and Sex  Grocery stores and supermarkets
# 4615466  3404908       4  Age and Sex  Grocery stores and supermarkets
# 4615476  3404909       4  Age and Sex  Grocery stores and supermarkets
# 4615481  3394889       4  Age and Sex  Grocery stores and supermarkets
#
#          timeofday             h3id  accessibility  population   pop x acc
# 11       afternoon  8929a5659dbffff       2.107254    0.000000    0.000000
# 26       afternoon  8929a565a03ffff       2.783466    0.000000    0.000000
# 41       afternoon  8929a565a03ffff       0.195717    0.000000    0.000000
# 56       afternoon  8929a565a03ffff      34.469766    0.000000    0.000000
# 71       afternoon  8929a565a03ffff       0.347431    0.000000    0.000000
# ...            ...              ...            ...         ...         ...
# 4615421  afternoon  892759359b7ffff       0.870483  318.250000  277.031085
# 4615456  afternoon  89275936a9bffff       0.527612  117.888889   62.199556
# 4615466  afternoon  89275936e43ffff       0.527612  119.500000   63.049597
# 4615476  afternoon  89275936e47ffff       0.527612  119.500000   63.049597
# 4615481  afternoon  89266450917ffff       0.566062   85.809524   48.573468
#
# [305659 rows x 9 columns]

# %%
acc_df_mrgd_fltrd = pd.merge(acc_df_mrgd_fltrd, city_pop_df, how='inner', on = 'cityid')
acc_df_mrgd_fltrd
# Out:
#              id  cityid categorytype                     poi_category  \
# 0       1647997       3  Age and Sex          Schools and pre-schools
# 1       2587058       3  Age and Sex              Vaccination centers
# 2       1896243       3  Age and Sex             Cinemas and Theaters
# 3       2108145       3  Age and Sex  Grocery stores and supermarkets
# 4       2346308       3  Age and Sex            Clinics and Hospitals
# ...         ...     ...          ...                              ...
# 305654  1416337       2  Age and Sex                      Restaurants
# 305655  1418023       2  Age and Sex                      Restaurants
# 305656   816793       2  Age and Sex          Schools and pre-schools
# 305657   816794       2  Age and Sex          Schools and pre-schools
# 305658   816902       2  Age and Sex          Schools and pre-schools
#
#         timeofday             h3id  accessibility  population  pop x acc  \
# 0       afternoon  8929a5659dbffff       2.107254    0.000000    0.00000
# 1       afternoon  8929a565a03ffff       2.783466    0.000000    0.00000
# 2       afternoon  8929a565a03ffff       0.195717    0.000000    0.00000
# 3       afternoon  8929a565a03ffff      34.469766    0.000000    0.00000
# 4       afternoon  8929a565a03ffff       0.347431    0.000000    0.00000
# ...           ...              ...            ...         ...        ...
# 305654  afternoon  892a103b067ffff       0.085901    0.000000    0.00000
# 305655  afternoon  892a106e4b7ffff       0.104970    0.000000    0.00000
# 305656  afternoon  892a100c963ffff       0.053793   77.666667    4.17791
# 305657  afternoon  892a100c96bffff       0.053793   77.666667    4.17791
# 305658  afternoon  892a100cba7ffff       0.053793   77.666667    4.17791
#
#              citypop
# 0       4.636897e+07
# 1       4.636897e+07
# 2       4.636897e+07
# 3       4.636897e+07
# 4       4.636897e+07
# ...              ...
# 305654  3.411227e+07
# 305655  3.411227e+07
# 305656  3.411227e+07
# 305657  3.411227e+07
# 305658  3.411227e+07
#
# [305659 rows x 10 columns]

# %%
acc_df_mrgd_fltrd["pop x acc / sum pop"] = acc_df_mrgd_fltrd["pop x acc"]/acc_df_mrgd_fltrd["citypop"]
acc_df_mrgd_fltrd
# Out:
#              id  cityid categorytype                     poi_category  \
# 0       1647997       3  Age and Sex          Schools and pre-schools
# 1       2587058       3  Age and Sex              Vaccination centers
# 2       1896243       3  Age and Sex             Cinemas and Theaters
# 3       2108145       3  Age and Sex  Grocery stores and supermarkets
# 4       2346308       3  Age and Sex            Clinics and Hospitals
# ...         ...     ...          ...                              ...
# 305654  1416337       2  Age and Sex                      Restaurants
# 305655  1418023       2  Age and Sex                      Restaurants
# 305656   816793       2  Age and Sex          Schools and pre-schools
# 305657   816794       2  Age and Sex          Schools and pre-schools
# 305658   816902       2  Age and Sex          Schools and pre-schools
#
#         timeofday             h3id  accessibility  population  pop x acc  \
# 0       afternoon  8929a5659dbffff       2.107254    0.000000    0.00000
# 1       afternoon  8929a565a03ffff       2.783466    0.000000    0.00000
# 2       afternoon  8929a565a03ffff       0.195717    0.000000    0.00000
# 3       afternoon  8929a565a03ffff      34.469766    0.000000    0.00000
# 4       afternoon  8929a565a03ffff       0.347431    0.000000    0.00000
# ...           ...              ...            ...         ...        ...
# 305654  afternoon  892a103b067ffff       0.085901    0.000000    0.00000
# 305655  afternoon  892a106e4b7ffff       0.104970    0.000000    0.00000
# 305656  afternoon  892a100c963ffff       0.053793   77.666667    4.17791
# 305657  afternoon  892a100c96bffff       0.053793   77.666667    4.17791
# 305658  afternoon  892a100cba7ffff       0.053793   77.666667    4.17791
#
#              citypop  pop x acc / sum pop
# 0       4.636897e+07         0.000000e+00
# 1       4.636897e+07         0.000000e+00
# 2       4.636897e+07         0.000000e+00
# 3       4.636897e+07         0.000000e+00
# 4       4.636897e+07         0.000000e+00
# ...              ...                  ...
# 305654  3.411227e+07         0.000000e+00
# 305655  3.411227e+07         0.000000e+00
# 305656  3.411227e+07         1.224753e-07
# 305657  3.411227e+07         1.224753e-07
# 305658  3.411227e+07         1.224753e-07
#
# [305659 rows x 11 columns]

# %%
city_level_acc = acc_df_mrgd_fltrd.drop("id", axis=1).groupby(["cityid","poi_category"]).mean()
city_level_acc
# Out:
#                                         accessibility  population  \
# cityid poi_category
# 1      Cinemas and Theaters                  0.991684  174.128047
#        Clinics and Hospitals                 0.871586  145.693476
#        Grocery stores and supermarkets       1.819306  134.051893
#        Restaurants                           6.180736  131.200579
#        Schools and pre-schools               3.701012  122.857171
#        Vaccination centers                   2.802883  129.314866
# 2      Cinemas and Theaters                  0.492520  825.851157
#        Clinics and Hospitals                 0.725608  740.681457
#        Grocery stores and supermarkets       6.918257  685.475355
#        Restaurants                          13.156869  668.355132
#        Schools and pre-schools               2.587240  659.838444
#        Vaccination centers                   3.117086  676.945977
# 3      Cinemas and Theaters                 19.957467  473.903504
#        Clinics and Hospitals                 0.445464  508.394817
#        Grocery stores and supermarkets       9.806198  424.599881
#        Restaurants                          10.078710  412.554727
#        Schools and pre-schools               8.052311  415.357240
#        Vaccination centers                   1.642808  415.378344
# 4      Cinemas and Theaters                  0.241877  517.089523
#        Clinics and Hospitals                 0.303166  425.014300
#        Grocery stores and supermarkets       3.336793  346.715578
#        Restaurants                          12.066193  356.746194
#        Schools and pre-schools               1.802505  362.176211
#        Vaccination centers                   1.596038  348.163521
# 5      Cinemas and Theaters                  0.922410  235.781504
#        Clinics and Hospitals                 0.783389  237.153090
#        Grocery stores and supermarkets       1.070147  221.559667
#        Restaurants                           4.375626  204.518551
#        Schools and pre-schools               1.506259  219.181156
#        Vaccination centers                   5.741270  203.589508
#
#                                           pop x acc       citypop  \
# cityid poi_category
# 1      Cinemas and Theaters              146.211786  6.598785e+06
#        Clinics and Hospitals             106.830690  6.598785e+06
#        Grocery stores and supermarkets   220.791168  6.598785e+06
#        Restaurants                       884.615385  6.598785e+06
#        Schools and pre-schools           394.736842  6.598785e+06
#        Vaccination centers               330.150510  6.598785e+06
# 2      Cinemas and Theaters              404.345202  3.411227e+07
#        Clinics and Hospitals             486.191024  3.411227e+07
#        Grocery stores and supermarkets  2822.250789  3.411227e+07
#        Restaurants                      6863.378243  3.411227e+07
#        Schools and pre-schools          1560.873048  3.411227e+07
#        Vaccination centers              1897.810219  3.411227e+07
# 3      Cinemas and Theaters              236.700538  4.636897e+07
#        Clinics and Hospitals             172.527473  4.636897e+07
#        Grocery stores and supermarkets   452.840936  4.636897e+07
#        Restaurants                      1781.973477  4.636897e+07
#        Schools and pre-schools           578.223871  4.636897e+07
#        Vaccination centers               664.973163  4.636897e+07
# 4      Cinemas and Theaters              147.913365  1.961160e+07
#        Clinics and Hospitals             123.476086  1.961160e+07
#        Grocery stores and supermarkets   605.670103  1.961160e+07
#        Restaurants                      2152.056901  1.961160e+07
#        Schools and pre-schools           654.370647  1.961160e+07
#        Vaccination centers               591.880144  1.961160e+07
# 5      Cinemas and Theaters              101.335790  9.861378e+06
#        Clinics and Hospitals             145.576708  9.861378e+06
#        Grocery stores and supermarkets   199.416910  9.861378e+06
#        Restaurants                       798.002803  9.861378e+06
#        Schools and pre-schools           191.693291  9.861378e+06
#        Vaccination centers               478.098854  9.861378e+06
#
#                                         pop x acc / sum pop
# cityid poi_category
# 1      Cinemas and Theaters                        0.000022
#        Clinics and Hospitals                       0.000016
#        Grocery stores and supermarkets             0.000033
#        Restaurants                                 0.000134
#        Schools and pre-schools                     0.000060
#        Vaccination centers                         0.000050
# 2      Cinemas and Theaters                        0.000012
#        Clinics and Hospitals                       0.000014
#        Grocery stores and supermarkets             0.000083
#        Restaurants                                 0.000201
#        Schools and pre-schools                     0.000046
#        Vaccination centers                         0.000056
# 3      Cinemas and Theaters                        0.000005
#        Clinics and Hospitals                       0.000004
#        Grocery stores and supermarkets             0.000010
#        Restaurants                                 0.000038
#        Schools and pre-schools                     0.000012
#        Vaccination centers                         0.000014
# 4      Cinemas and Theaters                        0.000008
#        Clinics and Hospitals                       0.000006
#        Grocery stores and supermarkets             0.000031
#        Restaurants                                 0.000110
#        Schools and pre-schools                     0.000033
#        Vaccination centers                         0.000030
# 5      Cinemas and Theaters                        0.000010
#        Clinics and Hospitals                       0.000015
#        Grocery stores and supermarkets             0.000020
#        Restaurants                                 0.000081
#        Schools and pre-schools                     0.000019
#        Vaccination centers                         0.000048

# %%
city_mapper = {1:"Atlanta", 2:"New York", 3:"Los Angeles", 4:"Chicago", 5:"Dallas"}

city_level_acc = city_level_acc.reset_index()
city_level_acc["city"] = city_level_acc["cityid"].map(city_mapper)
city_level_acc
# Out:
#     cityid                     poi_category  accessibility  population  \
# 0        1             Cinemas and Theaters       0.991684  174.128047
# 1        1            Clinics and Hospitals       0.871586  145.693476
# 2        1  Grocery stores and supermarkets       1.819306  134.051893
# 3        1                      Restaurants       6.180736  131.200579
# 4        1          Schools and pre-schools       3.701012  122.857171
# 5        1              Vaccination centers       2.802883  129.314866
# 6        2             Cinemas and Theaters       0.492520  825.851157
# 7        2            Clinics and Hospitals       0.725608  740.681457
# 8        2  Grocery stores and supermarkets       6.918257  685.475355
# 9        2                      Restaurants      13.156869  668.355132
# 10       2          Schools and pre-schools       2.587240  659.838444
# 11       2              Vaccination centers       3.117086  676.945977
# 12       3             Cinemas and Theaters      19.957467  473.903504
# 13       3            Clinics and Hospitals       0.445464  508.394817
# 14       3  Grocery stores and supermarkets       9.806198  424.599881
# 15       3                      Restaurants      10.078710  412.554727
# 16       3          Schools and pre-schools       8.052311  415.357240
# 17       3              Vaccination centers       1.642808  415.378344
# 18       4             Cinemas and Theaters       0.241877  517.089523
# 19       4            Clinics and Hospitals       0.303166  425.014300
# 20       4  Grocery stores and supermarkets       3.336793  346.715578
# 21       4                      Restaurants      12.066193  356.746194
# 22       4          Schools and pre-schools       1.802505  362.176211
# 23       4              Vaccination centers       1.596038  348.163521
# 24       5             Cinemas and Theaters       0.922410  235.781504
# 25       5            Clinics and Hospitals       0.783389  237.153090
# 26       5  Grocery stores and supermarkets       1.070147  221.559667
# 27       5                      Restaurants       4.375626  204.518551
# 28       5          Schools and pre-schools       1.506259  219.181156
# 29       5              Vaccination centers       5.741270  203.589508
#
#       pop x acc       citypop  pop x acc / sum pop         city
# 0    146.211786  6.598785e+06             0.000022      Atlanta
# 1    106.830690  6.598785e+06             0.000016      Atlanta
# 2    220.791168  6.598785e+06             0.000033      Atlanta
# 3    884.615385  6.598785e+06             0.000134      Atlanta
# 4    394.736842  6.598785e+06             0.000060      Atlanta
# 5    330.150510  6.598785e+06             0.000050      Atlanta
# 6    404.345202  3.411227e+07             0.000012     New York
# 7    486.191024  3.411227e+07             0.000014     New York
# 8   2822.250789  3.411227e+07             0.000083     New York
# 9   6863.378243  3.411227e+07             0.000201     New York
# 10  1560.873048  3.411227e+07             0.000046     New York
# 11  1897.810219  3.411227e+07             0.000056     New York
# 12   236.700538  4.636897e+07             0.000005  Los Angeles
# 13   172.527473  4.636897e+07             0.000004  Los Angeles
# 14   452.840936  4.636897e+07             0.000010  Los Angeles
# 15  1781.973477  4.636897e+07             0.000038  Los Angeles
# 16   578.223871  4.636897e+07             0.000012  Los Angeles
# 17   664.973163  4.636897e+07             0.000014  Los Angeles
# 18   147.913365  1.961160e+07             0.000008      Chicago
# 19   123.476086  1.961160e+07             0.000006      Chicago
# 20   605.670103  1.961160e+07             0.000031      Chicago
# 21  2152.056901  1.961160e+07             0.000110      Chicago
# 22   654.370647  1.961160e+07             0.000033      Chicago
# 23   591.880144  1.961160e+07             0.000030      Chicago
# 24   101.335790  9.861378e+06             0.000010       Dallas
# 25   145.576708  9.861378e+06             0.000015       Dallas
# 26   199.416910  9.861378e+06             0.000020       Dallas
# 27   798.002803  9.861378e+06             0.000081       Dallas
# 28   191.693291  9.861378e+06             0.000019       Dallas
# 29   478.098854  9.861378e+06             0.000048       Dallas

# %%
city_level_acc.to_csv("city_level_stats.csv", index=False)

# %% [markdown]
# ## Machine Learning

# %%
race_filter = h3_demographic_df["categorytype"] == "Race"
city_filter = h3_demographic_df["cityid"] == 1
h3_demo_race = h3_demographic_df[race_filter & city_filter]
h3_demo_race
# Out:
#          cityid categorytype                                   groupname  \
# 2566          1         Race                           Two or more races
# 2567          1         Race                             Some other race
# 2568          1         Race  Native Hawaiian and Other Pacific Islander
# 2569          1         Race                                       Asian
# 2570          1         Race           American Indian and Alaska Native
# ...         ...          ...                                         ...
# 3415218       1         Race  Native Hawaiian and Other Pacific Islander
# 3415219       1         Race                                       Asian
# 3415220       1         Race           American Indian and Alaska Native
# 3415221       1         Race                   Black or African American
# 3415222       1         Race                                       White
#
#                     h3id  population       id
# 2566     8944ccd829bffff    0.184466  1901211
# 2567     8944ccd829bffff    0.194175  1901212
# 2568     8944ccd829bffff    0.000000  1901213
# 2569     8944ccd829bffff    0.572816  1901214
# 2570     8944ccd829bffff    0.106796  1901215
# ...                  ...         ...      ...
# 3415218  8944c1383b7ffff    0.000000  1893888
# 3415219  8944c1383b7ffff   24.863636  1893889
# 3415220  8944c1383b7ffff    3.136364  1893890
# 3415221  8944c1383b7ffff   81.772727  1893891
# 3415222  8944c1383b7ffff   77.545455  1893892
#
# [173313 rows x 6 columns]

# %%
# finding the race with majority population in each H3 hexagon
idx = h3_demo_race.groupby(["h3id"])['population'].transform(max) == h3_demo_race['population']
machine_learning_df = h3_demo_race[idx][["h3id", "groupname"]]
machine_learning_df
# Out:
#                     h3id                  groupname
# 2572     8944ccd829bffff                      White
# 2597     8944ccd91a3ffff                      White
# 2622     8944c123527ffff                      White
# 2647     8944c12318fffff                      White
# 2672     8944c13219bffff                      White
# ...                  ...                        ...
# 3415121  8944c139d93ffff  Black or African American
# 3415146  8944c1b8267ffff  Black or African American
# 3415171  8944c1b836bffff  Black or African American
# 3415196  8944c106a5bffff  Black or African American
# 3415221  8944c1383b7ffff  Black or African American
#
# [26097 rows x 2 columns]

# %%
machine_learning_df = pd.merge(machine_learning_df, acc_df, how='inner', on = 'h3id')
category_filter = machine_learning_df["categorytype"] == "Race"
poi_filter = machine_learning_df["poi_category"] == "Vaccination centers"
time_filter = machine_learning_df["timeofday"] == "afternoon"

machine_learning_df = machine_learning_df[category_filter & poi_filter & time_filter]
machine_learning_df
# Out:
#                    h3id                  groupname      id  cityid  \
# 20      8944c12318fffff                      White  482405       1
# 65      8944c13219bffff                      White  483699       1
# 150     8944ccd824bffff                      White  491869       1
# 165     8944c12318bffff                      White  482404       1
# 210     8944ccd952fffff                      White  492052       1
# ...                 ...                        ...     ...     ...
# 783530  8944c1b826bffff  Black or African American  490674       1
# 783570  8944c139d93ffff  Black or African American  485302       1
# 783585  8944c1b8267ffff  Black or African American  490673       1
# 783625  8944c1b836bffff  Black or African American  490713       1
# 783655  8944c106a5bffff  Black or African American  481174       1
#
#        categorytype         poi_category  timeofday  accessibility
# 20             Race  Vaccination centers  afternoon       8.478673
# 65             Race  Vaccination centers  afternoon       2.988326
# 150            Race  Vaccination centers  afternoon       2.566048
# 165            Race  Vaccination centers  afternoon       8.478673
# 210            Race  Vaccination centers  afternoon       4.794596
# ...             ...                  ...        ...            ...
# 783530         Race  Vaccination centers  afternoon       0.383625
# 783570         Race  Vaccination centers  afternoon       1.440069
# 783585         Race  Vaccination centers  afternoon       0.383625
# 783625         Race  Vaccination centers  afternoon       8.593345
# 783655         Race  Vaccination centers  afternoon       1.017363
#
# [12748 rows x 8 columns]

# %%
from sklearn.model_selection import cross_val_score, GridSearchCV, cross_validate, train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler, normalize

# %%
x_data = machine_learning_df[["accessibility"]]
y_data = machine_learning_df["groupname"]
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, random_state=614, train_size=0.8)

# %%
# building a Random Forest model to predict the race with majority population based on accessibility, for each H3 hexagon
rf_clf = RandomForestClassifier(random_state=614)
rf_clf.fit(x_train,y_train)
y_predict_train = rf_clf.predict(x_train)
y_predict_test = rf_clf.predict(x_test)
# Out:
# /opt/miniconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['quoted_name']. An error will be raised in 1.2.
#   warnings.warn(
# /opt/miniconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['quoted_name']. An error will be raised in 1.2.
#   warnings.warn(
# /opt/miniconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['quoted_name']. An error will be raised in 1.2.
#   warnings.warn(

# %%
train_accuracy = accuracy_score(y_train,y_predict_train)
train_accuracy
# Out:
# 0.9047852520101981

# %%
test_accuracy = accuracy_score(y_test,y_predict_test)
test_accuracy
# Out:
# 0.8266666666666667

# %%
print(classification_report(y_train, y_predict_train))
# Out:
# /opt/miniconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/miniconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                             precision    recall  f1-score   support
#
#          American Indian and Alaska Native       0.19      0.24      0.21        67
#                                      Asian       0.77      0.35      0.48       179
#                  Black or African American       0.93      0.93      0.93      5275
# Native Hawaiian and Other Pacific Islander       0.00      0.00      0.00        54
#                            Some other race       0.63      0.35      0.45       125
#                          Two or more races       0.38      0.25      0.30        73
#                                      White       0.91      0.94      0.92      4425
#
#                                   accuracy                           0.90     10198
#                                  macro avg       0.54      0.44      0.47     10198
#                               weighted avg       0.90      0.90      0.90     10198
# /opt/miniconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(classification_report(y_test, y_predict_test))
# Out:
#                                             precision    recall  f1-score   support
#
#          American Indian and Alaska Native       0.00      0.00      0.00        10
#                                      Asian       0.35      0.16      0.22        37
#                  Black or African American       0.86      0.85      0.86      1320
# Native Hawaiian and Other Pacific Islander       0.00      0.00      0.00        11
#                            Some other race       0.38      0.11      0.17        45
#                          Two or more races       0.00      0.00      0.00        18
#                                      White       0.83      0.87      0.85      1109
#
#                                   accuracy                           0.83      2550
#                                  macro avg       0.35      0.29      0.30      2550
#                               weighted avg       0.82      0.83      0.82      2550
# /opt/miniconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/miniconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/miniconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
